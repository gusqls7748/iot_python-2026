# %% [markdown]
# ## 주피터 노트북 시작
#
# - 마크다운 쉘은 일반 md 파일에서 작성하는 것과 동일합니다.
#
# - [구글](https://www.google.com)과 같은 웹사이트 링크 사용가능
#
# - 주피터 노트북의 경로는 해당위치부터 시작
# -![이미지](../image-1.png)

# %%
print('Hello, jupyter')
# Out:
# Hello, jupyter
