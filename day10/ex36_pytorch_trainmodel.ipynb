# %% [markdown]
# ## 저장한 모델 사용하기

# %% [markdown]
# ## 1. 라이브러리 로드

# %% [markdown]
# ## 1. 라이브러리 로드

# %%
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim

import requests
from PIL import Image
from io import BytesIO
import os
import random
import shutil

# 사전학습 모델 라이브러리 추가
from torchvision.models import resnet18, ResNet18_Weights
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder

# pip install icrawler
from icrawler.builtin import BaiduImageCrawler, BingImageCrawler

import matplotlib.pyplot as plt

# %%
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.version.cuda)
print(torch.cuda.get_device_name(0))
# Out:
# 2.12.0+cu130
# True
# 13.0
# NVIDIA GeForce RTX 5060

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## 2.설정

# %%
model_path = 'resnet18_bird_cat_dog.pth'
test_dir = 'dataset/test'

num_classes = 3
batch_size = 16

# %% [markdown]
# ### 3. ResNet18 모델구조 재생성

# %%
weight = ResNet18_Weights.DEFAULT
model = resnet18(weights=weight)

model.fc = nn.Linear(
    in_features=model.fc.in_features,
    out_features=num_classes
)

model = model.to(device=device)

# %% [markdown]
# ## 4. pth 모델파일 구조

# %%
model.load_state_dict(
    torch.load(model_path, map_location=device)
)

model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=3, bias=True)
# )

# %% [markdown]
# ## 5. 전처리 설정

# %%
preprocess = weight.transforms()
preprocess
# Out:
# ImageClassification(
#     crop_size=[224]
#     resize_size=[256]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BILINEAR
# )

# %% [markdown]
# ### 6. 바이두 이미지크롤링
# - 테스트이미지 셋 다운로드

# %%
# 추가 설정
# 추가설정
testset_dir = 'dataset/test'

classes = {
    'dog photo': 'dog',
    'cat photo': 'cat',
    'bird photo': 'bird'
}

num_epoch = 5
lr = 0.001

# %%
# 테스트이미지 폴더
for keyword, class_name in classes.items():
    save_dir = os.path.join(testset_dir, class_name)
    os.makedirs(save_dir, exist_ok=True)

    crawler = BaiduImageCrawler(
        storage={'root_dir': save_dir}
    )

    crawler.crawl(
        keyword=keyword,
        max_num=150
    )
# Out:
# 2026-05-21 16:27:41,187 - INFO - icrawler.crawler - start crawling...
# 2026-05-21 16:27:41,189 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2026-05-21 16:27:41,189 - INFO - feeder - thread feeder-001 exit
# 2026-05-21 16:27:41,191 - INFO - icrawler.crawler - starting 1 parser threads...
# 2026-05-21 16:27:41,193 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2026-05-21 16:27:42,600 - INFO - parser - parsing result page http://image.baidu.com/search/acjson?tn=resultjson_com&ipn=rj&word=dog photo&pn=0&rn=30
# 2026-05-21 16:27:42,604 - INFO - downloader - skip downloading file 000001.jpg
# 2026-05-21 16:27:42,605 - INFO - downloader - skip downloading file 000002.jpg
# 2026-05-21 16:27:42,606 - INFO - downloader - skip downloading file 000003.jpg
# 2026-05-21 16:27:42,606 - INFO - downloader - skip downloading file 000004.jpg
# 2026-05-21 16:27:42,607 - INFO - downloader - skip downloading file 000005.jpg
# 2026-05-21 16:27:42,608 - INFO - downloader - skip downloading file 000006.jpg
# 2026-05-21 16:27:42,608 - INFO - downloader - skip downloading file 000007.jpg
# 2026-05-21 16:27:42,609 - INFO - downloader - skip downloading file 000008.jpg
# 2026-05-21 16:27:42,609 - INFO - downloader - skip downloading file 000009.jpg
# 2026-05-21 16:27:42,610 - INFO - downloader - skip downloading file 000010.jpg
# 2026-05-21 16:27:42,610 - INFO - downloader - skip downloading file 000011.jpg
# 2026-05-21 16:27:42,610 - INFO - downloader - skip downloading file 000012.jpg
(Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1010)'))), remaining retry times: 0
# 2026-05-21 16:27:50,033 - INFO - downloader - image #40	https://permies.com/t/59154/a/43842/DSC03962.JPG
# 2026-05-21 16:27:50,036 - INFO - downloader - skip downloading file 000041.jpg
# 2026-05-21 16:27:50,037 - INFO - downloader - skip downloading file 000042.jpg
# 2026-05-21 16:27:50,037 - INFO - downloader - skip downloading file 000043.jpg
# 2026-05-21 16:27:50,038 - INFO - downloader - skip downloading file 000044.jpg
# 2026-05-21 16:27:50,038 - INFO - downloader - skip downloading file 000045.jpg
# 2026-05-21 16:27:50,039 - INFO - downloader - skip downloading file 000046.jpg
# 2026-05-21 16:27:50,039 - INFO - downloader - skip downloading file 000047.jpg
# 2026-05-21 16:27:50,393 - INFO - downloader - image #48	https://www.globaltimes.cn/Portals/0/attachment/2025/2025-08-31/d6386f66-cb31-4a66-af99-6b66d98cd504.jpeg
# 2026-05-21 16:27:52,971 - INFO - parser - parsing result page http://image.baidu.com/search/acjson?tn=resultjson_com&ipn=rj&word=dog photo&pn=60&rn=30
# 2026-05-21 16:27:54,553 - INFO - downloader - image #49	https://best-wallpaper.net/wallpaper/iphone/1712/Dog-rest-stump_iphone_640x1136.jpg
# 2026-05-21 16:27:54,555 - INFO - downloader - skip downloading file 000050.jpg
# 2026-05-21 16:27:54,555 - INFO - downloader - skip downloading file 000051.jpg
# 2026-05-21 16:27:54,555 - INFO - downloader - skip downloading file 000052.jpg
# 2026-05-21 16:27:54,556 - INFO - downloader - skip downloading file 000053.jpg
# 2026-05-21 16:27:54,556 - INFO - downloader - skip downloading file 000054.jpg
# 2026-05-21 16:27:54,985 - INFO - downloader - skip downloading file 000055.jpg
# 2026-05-21 16:27:54,986 - INFO - downloader - skip downloading file 000056.jpg
# 2026-05-21 16:27:54,987 - INFO - downloader - skip downloading file 000057.jpg
# 2026-05-21 16:27:54,987 - INFO - downloader - skip downloading file 000058.jpg
# 2026-05-21 16:27:54,988 - INFO - downloader - skip downloading file 000059.jpg
# 2026-05-21 16:27:54,988 - INFO - downloader - skip downloading file 000060.jpg
# 2026-05-21 16:27:54,989 - INFO - downloader - skip downloading file 000061.jpg
# 2026-05-21 16:27:54,989 - INFO - downloader - skip downloading file 000062.jpg
# 2026-05-21 16:27:54,990 - INFO - downloader - skip downloading file 000063.jpg
# 2026-05-21 16:27:54,992 - INFO - downloader - skip downloading file 000064.jpg
# 2026-05-21 16:27:54,992 - INFO - downloader - skip downloading file 000065.jpg
# 2026-05-21 16:27:54,993 - INFO - downloader - skip downloading file 000066.jpg
# 2026-05-21 16:27:54,993 - INFO - downloader - skip downloading file 000067.jpg
# 2026-05-21 16:27:54,994 - INFO - downloader - skip downloading file 000068.jpg
# 2026-05-21 16:27:55,606 - INFO - parser - parsing result page http://image.baidu.com/search/acjson?tn=resultjson_com&ipn=rj&word=dog photo&pn=90&rn=30
# 2026-05-21 16:27:55,608 - INFO - downloader - skip downloading file 000069.jpg
# 2026-05-21 16:27:56,637 - INFO - downloader - image #70	https://townsquare.media/site/564/files/2025/08/attachment-img_1558-1.jpeg?w=3024&h=4032&q=75
# 2026-05-21 16:27:56,639 - INFO - downloader - skip downloading file 000071.jpg
# 2026-05-21 16:27:56,639 - INFO - downloader - skip downloading file 000072.jpg
# 2026-05-21 16:27:56,639 - INFO - downloader - skip downloading file 000073.jpg
# 2026-05-21 16:28:04,056 - INFO - downloader - image #96	https://hellorfimg.zcool.cn/large/1781637926.jpg
# 2026-05-21 16:28:04,233 - INFO - downloader - image #97	https://hellorfimg.zcool.cn/large/1074577871.jpg
# 2026-05-21 16:28:09,246 - INFO - downloader - no more download task for thread downloader-001
# 2026-05-21 16:28:09,246 - INFO - downloader - thread downloader-001 exit
# 2026-05-21 16:28:10,206 - INFO - icrawler.crawler - Crawling task done!
# 2026-05-21 16:28:10,207 - INFO - icrawler.crawler - start crawling...
# 2026-05-21 16:28:10,207 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2026-05-21 16:28:10,209 - INFO - feeder - thread feeder-001 exit
# 2026-05-21 16:28:10,230 - INFO - icrawler.crawler - starting 1 parser threads...
# 2026-05-21 16:28:10,234 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2026-05-21 16:28:11,695 - INFO - parser - parsing result page http://image.baidu.com/search/acjson?tn=resultjson_com&ipn=rj&word=cat photo&pn=0&rn=30
# 2026-05-21 16:28:11,698 - INFO - downloader - skip downloading file 000001.jpg
# 2026-05-21 16:28:11,706 - INFO - downloader - skip downloading file 000002.jpg
# 2026-05-21 16:28:11,706 - INFO - downloader - skip downloading file 000003.jpg
# 2026-05-21 16:28:11,707 - INFO - downloader - skip downloading file 000004.jpg
# 2026-05-21 16:28:11,707 - INFO - downloader - skip downloading file 000005.jpg
# 2026-05-21 16:28:11,710 - INFO - downloader - skip downloading file 000006.jpg
# 2026-05-21 16:28:11,711 - INFO - downloader - skip downloading file 000007.jpg
# 2026-05-21 16:28:11,711 - INFO - downloader - skip downloading file 000008.jpg
# 2026-05-21 16:28:11,712 - INFO - downloader - skip downloading file 000009.jpg
# 2026-05-21 16:28:11,712 - INFO - downloader - skip downloading file 000010.jpg
# 2026-05-21 16:28:11,713 - INFO - downloader - skip downloading file 000011.jpg
# 2026-05-21 16:28:11,713 - INFO - downloader - skip downloading file 000012.jpg
# 2026-05-21 16:28:11,713 - INFO - downloader - skip downloading file 000013.jpg
# 2026-05-21 16:28:11,714 - INFO - downloader - skip downloading file 000014.jpg
# 2026-05-21 16:28:11,714 - INFO - downloader - skip downloading file 000015.jpg
# 2026-05-21 16:28:11,715 - INFO - downloader - skip downloading file 000016.jpg
# 2026-05-21 16:28:11,715 - INFO - downloader - skip downloading file 000017.jpg
# 2026-05-21 16:28:11,716 - INFO - downloader - skip downloading file 000018.jpg
# 2026-05-21 16:28:11,716 - INFO - downloader - skip downloading file 000019.jpg
# 2026-05-21 16:28:11,717 - INFO - downloader - skip downloading file 000020.jpg
# 2026-05-21 16:28:11,719 - INFO - downloader - skip downloading file 000021.jpg
# 2026-05-21 16:28:11,720 - INFO - downloader - skip downloading file 000022.jpg
# 2026-05-21 16:28:11,721 - INFO - downloader - skip downloading file 000023.jpg
# 2026-05-21 16:28:11,722 - INFO - downloader - skip downloading file 000024.jpg
# 2026-05-21 16:28:11,722 - INFO - downloader - skip downloading file 000025.jpg
# 2026-05-21 16:28:11,723 - INFO - downloader - skip downloading file 000026.jpg
# 2026-05-21 16:28:11,724 - INFO - downloader - skip downloading file 000027.jpg
# 2026-05-21 16:28:11,724 - INFO - downloader - skip downloading file 000028.jpg
# 2026-05-21 16:28:11,724 - INFO - downloader - skip downloading file 000029.jpg
# 2026-05-21 16:28:11,725 - INFO - downloader - skip downloading file 000030.jpg
# 2026-05-21 16:28:12,285 - INFO - parser - parsing result page http://image.baidu.com/search/acjson?tn=resultjson_com&ipn=rj&word=cat photo&pn=30&rn=30
# 2026-05-21 16:28:12,287 - INFO - downloader - skip downloading file 000031.jpg
# 2026-05-21 16:28:12,288 - INFO - downloader - skip downloading file 000032.jpg
# 2026-05-21 16:28:12,289 - INFO - downloader - skip downloading file 000033.jpg
# 2026-05-21 16:28:12,289 - INFO - downloader - skip downloading file 000034.jpg
# 2026-05-21 16:28:12,290 - INFO - downloader - skip downloading file 000035.jpg
# 2026-05-21 16:28:12,292 - INFO - downloader - skip downloading file 000036.jpg
# 2026-05-21 16:28:12,292 - INFO - downloader - skip downloading file 000037.jpg
# 2026-05-21 16:28:12,293 - INFO - downloader - skip downloading file 000038.jpg
# 2026-05-21 16:28:12,294 - INFO - downloader - skip downloading file 000039.jpg
# 2026-05-21 16:28:12,294 - INFO - downloader - skip downloading file 000040.jpg
# 2026-05-21 16:28:12,295 - INFO - downloader - skip downloading file 000041.jpg
# 2026-05-21 16:28:12,296 - INFO - downloader - skip downloading file 000042.jpg
# 2026-05-21 16:28:12,296 - INFO - downloader - skip downloading file 000043.jpg
# 2026-05-21 16:28:12,297 - INFO - downloader - skip downloading file 000044.jpg
# 2026-05-21 16:28:12,297 - INFO - downloader - skip downloading file 000045.jpg
# 2026-05-21 16:28:12,298 - INFO - downloader - skip downloading file 000046.jpg
# 2026-05-21 16:28:12,299 - INFO - downloader - skip downloading file 000047.jpg
# 2026-05-21 16:28:12,301 - INFO - downloader - skip downloading file 000048.jpg
# 2026-05-21 16:28:12,302 - INFO - downloader - skip downloading file 000049.jpg
# 2026-05-21 16:28:12,303 - INFO - downloader - skip downloading file 000050.jpg
# 2026-05-21 16:28:12,304 - INFO - downloader - skip downloading file 000051.jpg
# 2026-05-21 16:28:12,305 - INFO - downloader - skip downloading file 000052.jpg
# 2026-05-21 16:28:12,306 - INFO - downloader - skip downloading file 000053.jpg
# 2026-05-21 16:28:12,306 - INFO - downloader - skip downloading file 000054.jpg
# 2026-05-21 16:28:12,307 - INFO - downloader - skip downloading file 000055.jpg
# 2026-05-21 16:28:12,309 - INFO - downloader - skip downloading file 000056.jpg
# 2026-05-21 16:28:12,309 - INFO - downloader - skip downloading file 000057.jpg
# 2026-05-21 16:28:12,310 - INFO - downloader - skip downloading file 000058.jpg
# 2026-05-21 16:28:12,310 - INFO - downloader - skip downloading file 000059.jpg
# 2026-05-21 16:28:12,310 - INFO - downloader - skip downloading file 000060.jpg
# 2026-05-21 16:28:12,861 - INFO - parser - parsing result page http://image.baidu.com/search/acjson?tn=resultjson_com&ipn=rj&word=cat photo&pn=60&rn=30
# 2026-05-21 16:28:12,862 - INFO - downloader - skip downloading file 000061.jpg
# 2026-05-21 16:28:12,862 - INFO - downloader - skip downloading file 000062.jpg
# 2026-05-21 16:28:12,863 - INFO - downloader - skip downloading file 000063.jpg
# 2026-05-21 16:28:12,863 - INFO - downloader - skip downloading file 000064.jpg
# 2026-05-21 16:28:12,864 - INFO - downloader - skip downloading file 000065.jpg
# 2026-05-21 16:28:25,794 - INFO - downloader - skip downloading file 000007.jpg
# 2026-05-21 16:28:25,795 - INFO - downloader - skip downloading file 000008.jpg
# 2026-05-21 16:28:25,795 - INFO - downloader - skip downloading file 000009.jpg
# 2026-05-21 16:28:25,795 - INFO - downloader - skip downloading file 000010.jpg
# 2026-05-21 16:28:25,796 - INFO - downloader - skip downloading file 000011.jpg
# 2026-05-21 16:28:25,797 - INFO - downloader - skip downloading file 000012.jpg
# 2026-05-21 16:28:25,797 - INFO - downloader - skip downloading file 000013.jpg
# 2026-05-21 16:28:25,797 - INFO - downloader - skip downloading file 000014.jpg
# 2026-05-21 16:28:25,798 - INFO - downloader - skip downloading file 000015.jpg
# 2026-05-21 16:28:25,799 - INFO - downloader - skip downloading file 000016.jpg
# 2026-05-21 16:28:25,799 - INFO - downloader - skip downloading file 000017.jpg
# 2026-05-21 16:28:25,800 - INFO - downloader - skip downloading file 000018.jpg
# 2026-05-21 16:28:25,801 - INFO - downloader - skip downloading file 000019.jpg
# 2026-05-21 16:28:25,801 - INFO - downloader - skip downloading file 000020.jpg
# 2026-05-21 16:28:25,802 - INFO - downloader - skip downloading file 000021.jpg
# 2026-05-21 16:28:25,802 - INFO - downloader - skip downloading file 000022.jpg
# 2026-05-21 16:28:30,430 - INFO - parser - parsing result page http://image.baidu.com/search/acjson?tn=resultjson_com&ipn=rj&word=bird photo&pn=30&rn=30
# 2026-05-21 16:28:31,049 - ERROR - downloader - Exception caught when downloading file https://www.adobe.com/de/creativecloud/photography/discover/media_1e512d5b405f1789b3fc3d107be968cf0ec279453.png?width=750&format=png&optimize=medium, error: HTTPSConnectionPool(host='www.adobe.com', port=443): Read timed out. (read timeout=5), remaining retry times: 2
# 2026-05-21 16:28:36,240 - ERROR - downloader - Exception caught when downloading file https://www.adobe.com/de/creativecloud/photography/discover/media_1e512d5b405f1789b3fc3d107be968cf0ec279453.png?width=750&format=png&optimize=medium, error: HTTPSConnectionPool(host='www.adobe.com', port=443): Read timed out. (read timeout=5), remaining retry times: 1
# 2026-05-21 16:28:41,438 - ERROR - downloader - Exception caught when downloading file https://www.adobe.com/de/creativecloud/photography/discover/media_1e512d5b405f1789b3fc3d107be968cf0ec279453.png?width=750&format=png&optimize=medium, error: HTTPSConnectionPool(host='www.adobe.com', port=443): Read timed out. (read timeout=5), remaining retry times: 0
# 2026-05-21 16:28:41,438 - INFO - downloader - skip downloading file 000023.jpg
# 2026-05-21 16:28:41,439 - INFO - downloader - skip downloading file 000024.jpg
# 2026-05-21 16:28:41,439 - INFO - downloader - skip downloading file 000025.jpg
# 2026-05-21 16:28:41,441 - INFO - downloader - skip downloading file 000026.jpg
# 2026-05-21 16:28:41,441 - INFO - downloader - skip downloading file 000027.jpg
# 2026-05-21 16:28:41,442 - INFO - downloader - skip downloading file 000028.jpg
# 2026-05-21 16:28:41,442 - INFO - downloader - skip downloading file 000029.jpg
# 2026-05-21 16:28:41,443 - INFO - downloader - skip downloading file 000030.jpg
# 2026-05-21 16:28:41,443 - INFO - downloader - skip downloading file 000031.jpg
# 2026-05-21 16:28:41,443 - INFO - downloader - skip downloading file 000032.jpg
# 2026-05-21 16:28:41,444 - INFO - downloader - skip downloading file 000033.jpg
# 2026-05-21 16:28:41,444 - INFO - downloader - skip downloading file 000034.jpg
# 2026-05-21 16:28:41,444 - INFO - downloader - skip downloading file 000035.jpg
# 2026-05-21 16:28:41,444 - INFO - downloader - skip downloading file 000036.jpg
# 2026-05-21 16:28:41,445 - INFO - downloader - skip downloading file 000037.jpg
# 2026-05-21 16:28:41,445 - INFO - downloader - skip downloading file 000038.jpg
# 2026-05-21 16:28:41,445 - INFO - downloader - skip downloading file 000039.jpg
# 2026-05-21 16:28:41,446 - INFO - downloader - skip downloading file 000040.jpg
# 2026-05-21 16:28:41,446 - INFO - downloader - skip downloading file 000041.jpg
# 2026-05-21 16:28:41,447 - INFO - downloader - skip downloading file 000042.jpg
# 2026-05-21 16:28:41,447 - INFO - downloader - skip downloading file 000043.jpg
# 2026-05-21 16:28:41,447 - INFO - downloader - skip downloading file 000044.jpg
# 2026-05-21 16:28:41,448 - INFO - downloader - skip downloading file 000045.jpg
# 2026-05-21 16:28:41,448 - INFO - downloader - skip downloading file 000046.jpg
# 2026-05-21 16:28:41,450 - INFO - downloader - skip downloading file 000047.jpg
# 2026-05-21 16:28:41,450 - INFO - downloader - skip downloading file 000048.jpg
# 2026-05-21 16:28:41,451 - INFO - downloader - skip downloading file 000049.jpg
# 2026-05-21 16:28:41,452 - INFO - downloader - skip downloading file 000050.jpg
# 2026-05-21 16:28:41,452 - INFO - downloader - skip downloading file 000051.jpg
# 2026-05-21 16:28:42,094 - INFO - parser - parsing result page http://image.baidu.com/search/acjson?tn=resultjson_com&ipn=rj&word=bird photo&pn=60&rn=30
# 2026-05-21 16:28:42,095 - INFO - downloader - skip downloading file 000052.jpg
# 2026-05-21 16:28:42,095 - INFO - downloader - skip downloading file 000053.jpg
# 2026-05-21 16:28:42,096 - INFO - downloader - skip downloading file 000054.jpg
# 2026-05-21 16:28:42,096 - INFO - downloader - skip downloading file 000055.jpg
# 2026-05-21 16:28:42,097 - INFO - downloader - skip downloading file 000056.jpg
# 2026-05-21 16:28:42,097 - INFO - downloader - skip downloading file 000057.jpg
# 2026-05-21 16:28:42,097 - INFO - downloader - skip downloading file 000058.jpg
# 2026-05-21 16:28:42,098 - INFO - downloader - skip downloading file 000059.jpg
# 2026-05-21 16:28:42,098 - INFO - downloader - skip downloading file 000060.jpg
# 2026-05-21 16:28:42,100 - INFO - downloader - skip downloading file 000061.jpg
# 2026-05-21 16:28:42,101 - INFO - downloader - skip downloading file 000062.jpg
# 2026-05-21 16:28:42,101 - INFO - downloader - skip downloading file 000063.jpg
# 2026-05-21 16:28:42,102 - INFO - downloader - skip downloading file 000064.jpg
# 2026-05-21 16:28:42,103 - INFO - downloader - skip downloading file 000065.jpg
# 2026-05-21 16:28:42,104 - INFO - downloader - skip downloading file 000066.jpg
# 2026-05-21 16:28:42,104 - INFO - downloader - skip downloading file 000067.jpg
# 2026-05-21 16:28:42,105 - INFO - downloader - skip downloading file 000068.jpg
# 2026-05-21 16:28:42,105 - INFO - downloader - skip downloading file 000069.jpg
# 2026-05-21 16:28:42,753 - INFO - parser - parsing result page http://image.baidu.com/search/acjson?tn=resultjson_com&ipn=rj&word=bird photo&pn
# 2026-05-21 16:28:48,593 - INFO - downloader - image #93	https://hellorfimg.zcool.cn/large/1169626465.jpg
# 2026-05-21 16:28:49,545 - INFO - downloader - image #94	https://gimg2.baidu.com/image_search/src=http%3A%2F%2Fss2.meipian.me%2Fusers%2F700773%2F848d1e73eae844888ae047ce86a9ae8b.jpg%3Fmeipian-raw%2Fbucket%2Fivwen%2Fkey%2FdXNlcnMvNzAwNzczLzg0OGQxZTczZWFlODQ0ODg4YWUwNDdjZTg2YTlhZThiLmpwZw%3D%3D%2Fsign%2Fda15fbe1da22eae75b767bb6eafedc4d.jpg&refer=http%3A%2F%2Fss2.meipian.me&app=2002&size=f9999,10000&q=a80&n=0&g=0n&fmt=auto?sec=1781940523&t=9ceb9f6f1f913584ca1ef1c5cd744e73
# 2026-05-21 16:28:49,807 - INFO - downloader - image #95	https://img14.360buyimg.com/pop/jfs/t1/200274/31/7779/22628/613b0605Ea731cf6d/8ff323ed6053a17d.jpg
# 2026-05-21 16:28:49,969 - INFO - downloader - image #96	https://hellorfimg.zcool.cn/large/1624933654.jpg?x-image-process=image/format,webp
# 2026-05-21 16:28:50,040 - INFO - downloader - image #97	https://hellorfimg.zcool.cn/large/510065773.jpg
# 2026-05-21 16:28:50,318 - INFO - downloader - image #98	https://img.alicdn.com/bao/uploaded/i2/2221348237937/O1CN01CSVPB61zxISnchRjK_%21%214611686018427385036-0-item_pic.jpg
# 2026-05-21 16:28:50,396 - INFO - parser - no more page urls for thread parser-001 to parse
# 2026-05-21 16:28:50,397 - INFO - parser - thread parser-001 exit
# 2026-05-21 16:28:55,333 - INFO - downloader - no more download task for thread downloader-001
# 2026-05-21 16:28:55,335 - INFO - downloader - thread downloader-001 exit
# 2026-05-21 16:28:56,278 - INFO - icrawler.crawler - Crawling task done!

# %% [markdown]
# ### 7. test 데이터셋 불러오기
# - dataset/train 폴더 내 데이터셋 로드

# %%
test_dataset = ImageFolder(
    root=test_dir,
    transform=preprocess
)
test_dataset.classes
# Out:
# ['bird', 'cat', 'dog']

# %%
test_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False
)

# %% [markdown]
# ## 8. test 정확도 확인

# %%
correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        _, predict = torch.max(outputs, 1)

        correct += (predict == labels).sum().item()
        total += labels.size(0)

test_acc = correct / total

print(f'테스트 정확도 : {test_acc:.4f}')
# Out:
# 테스트 정확도 : 0.9304

# %% [markdown]
# ## 9. 실제/ 예측값 출력

# %%
class_names = test_dataset.classes

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        # 1. 오타 수정: sortmax -> softmax
        prob = torch.softmax(outputs, dim=1)
        confidence, predict = torch.max(prob, 1)

        for i in range(len(labels)):
            true_label = class_names[labels[i].item()]
            
            # 2. 소괄호()를 대괄호[]로 수정: predict(i) -> predict[i]
            pred_label = class_names[predict[i].item()]
            
            # 3. 변수 이름 오타 수정: conf -> confidence
            conf = confidence[i].item()

            print(f'실제 : {true_label} / 예측 : {pred_label} / 확률 : {conf:.4f}')
# Out:
# 실제 : bird / 예측 : bird / 확률 : 0.9906
# 실제 : bird / 예측 : bird / 확률 : 0.9414
# 실제 : bird / 예측 : bird / 확률 : 0.9799
# 실제 : bird / 예측 : bird / 확률 : 0.9742
# 실제 : bird / 예측 : bird / 확률 : 0.9713
# 실제 : bird / 예측 : bird / 확률 : 0.8957
# 실제 : bird / 예측 : bird / 확률 : 0.9807
# 실제 : bird / 예측 : bird / 확률 : 0.9633
# 실제 : bird / 예측 : bird / 확률 : 0.9601
# 실제 : bird / 예측 : bird / 확률 : 0.9797
# 실제 : bird / 예측 : bird / 확률 : 0.9248
# 실제 : bird / 예측 : bird / 확률 : 0.9641
# 실제 : bird / 예측 : bird / 확률 : 0.7775
# 실제 : bird / 예측 : bird / 확률 : 0.9081
# 실제 : bird / 예측 : bird / 확률 : 0.9852
# 실제 : bird / 예측 : bird / 확률 : 0.9549
# 실제 : bird / 예측 : bird / 확률 : 0.9179
# 실제 : bird / 예측 : bird / 확률 : 0.9589
# 실제 : bird / 예측 : bird / 확률 : 0.9187
# 실제 : bird / 예측 : bird / 확률 : 0.9656
# 실제 : bird / 예측 : bird / 확률 : 0.9540
# 실제 : bird / 예측 : bird / 확률 : 0.9615
# 실제 : bird / 예측 : bird / 확률 : 0.7236
# 실제 : bird / 예측 : bird / 확률 : 0.9187
# 실제 : bird / 예측 : bird / 확률 : 0.8706
# 실제 : bird / 예측 : bird / 확률 : 0.9540
# 실제 : bird / 예측 : bird / 확률 : 0.9615
# 실제 : bird / 예측 : bird / 확률 : 0.7236
# 실제 : bird / 예측 : bird / 확률 : 0.9615
# 실제 : bird / 예측 : bird / 확률 : 0.7236
# 실제 : bird / 예측 : bird / 확률 : 0.8706
# 실제 : bird / 예측 : bird / 확률 : 0.8330
# 실제 : bird / 예측 : bird / 확률 : 0.8706
# 실제 : bird / 예측 : bird / 확률 : 0.9802
# 실제 : bird / 예측 : bird / 확률 : 0.9021
# 실제 : bird / 예측 : bird / 확률 : 0.9644
# 실제 : bird / 예측 : bird / 확률 : 0.8913
# 실제 : bird / 예측 : bird / 확률 : 0.9807
# 실제 : bird / 예측 : bird / 확률 : 0.9695
# 실제 : bird / 예측 : bird / 확률 : 0.9460
# 실제 : bird / 예측 : bird / 확률 : 0.8602
# 실제 : bird / 예측 : bird / 확률 : 0.8587
# 실제 : bird / 예측 : bird / 확률 : 0.9627
# 실제 : bird / 예측 : bird / 확률 : 0.7158
# 실제 : bird / 예측 : bird / 확률 : 0.8628
# 실제 : bird / 예측 : bird / 확률 : 0.9451
# 실제 : bird / 예측 : bird / 확률 : 0.8643
# 실제 : bird / 예측 : bird / 확률 : 0.9480
# 실제 : bird / 예측 : bird / 확률 : 0.9359
# 실제 : bird / 예측 : bird / 확률 : 0.9572
# 실제 : bird / 예측 : bird / 확률 : 0.9937
# 실제 : bird / 예측 : bird / 확률 : 0.7920
# 실제 : bird / 예측 : bird / 확률 : 0.6813
# 실제 : bird / 예측 : bird / 확률 : 0.9723
# 실제 : bird / 예측 : bird / 확률 : 0.7375
# 실제 : bird / 예측 : bird / 확률 : 0.9311
# 실제 : bird / 예측 : bird / 확률 : 0.7314
# 실제 : bird / 예측 : bird / 확률 : 0.7777
# 실제 : bird / 예측 : bird / 확률 : 0.7858
# 실제 : bird / 예측 : bird / 확률 : 0.8941
# 실제 : bird / 예측 : bird / 확률 : 0.9156
# 실제 : bird / 예측 : bird / 확률 : 0.9890
# 실제 : bird / 예측 : bird / 확률 : 0.8521
# 실제 : bird / 예측 : bird / 확률 : 0.6392
# 실제 : bird / 예측 : bird / 확률 : 0.8635
# 실제 : bird / 예측 : bird / 확률 : 0.9871
# 실제 : bird / 예측 : bird / 확률 : 0.7319
# 실제 : bird / 예측 : bird / 확률 : 0.7601
# 실제 : bird / 예측 : bird / 확률 : 0.9436
# 실제 : bird / 예측 : bird / 확률 : 0.9507
# 실제 : bird / 예측 : bird / 확률 : 0.9917
# 실제 : bird / 예측 : bird / 확률 : 0.9739
# 실제 : bird / 예측 : bird / 확률 : 0.9773
# 실제 : bird / 예측 : bird / 확률 : 0.8138
# 실제 : bird / 예측 : bird / 확률 : 0.8349
# 실제 : bird / 예측 : bird / 확률 : 0.9957
# 실제 : bird / 예측 : bird / 확률 : 0.9748
# 실제 : bird / 예측 : bird / 확률 : 0.9337
# 실제 : bird / 예측 : bird / 확률 : 0.9785
# 실제 : bird / 예측 : bird / 확률 : 0.8796
# 실제 : bird / 예측 : bird / 확률 : 0.4194
# 실제 : bird / 예측 : bird / 확률 : 0.9266
# 실제 : bird / 예측 : bird / 확률 : 0.9654
# 실제 : bird / 예측 : bird / 확률 : 0.8721
# 실제 : bird / 예측 : bird / 확률 : 0.6823
# 실제 : bird / 예측 : bird / 확률 : 0.9917
# 실제 : bird / 예측 : bird / 확률 : 0.9739
# 실제 : bird / 예측 : bird / 확률 : 0.9773
# 실제 : bird / 예측 : bird / 확률 : 0.9434
# 실제 : bird / 예측 : bird / 확률 : 0.8138
# 실제 : bird / 예측 : bird / 확률 : 0.8349
# 실제 : bird / 예측 : bird / 확률 : 0.9957
# 실제 : bird / 예측 : bird / 확률 : 0.9748
# 실제 : bird / 예측 : bird / 확률 : 0.9337
# 실제 : bird / 예측 : bird / 확률 : 0.9785
# 실제 : bird / 예측 : bird / 확률 : 0.8796
# 실제 : bird / 예측 : bird / 확률 : 0.4194
# 실제 : bird / 예측 : bird / 확률 : 0.9266
# 실제 : bird / 예측 : bird / 확률 : 0.9654
# 실제 : bird / 예측 : bird / 확률 : 0.8721
# 실제 : bird / 예측 : bird / 확률 : 0.6823
# 실제 : cat / 예측 : cat / 확률 : 0.9234
# 실제 : cat / 예측 : cat / 확률 : 0.9227
# 실제 : cat / 예측 : cat / 확률 : 0.9035
# 실제 : cat / 예측 : cat / 확률 : 0.9562
# 실제 : cat / 예측 : cat / 확률 : 0.8573
# 실제 : cat / 예측 : cat / 확률 : 0.9516
# 실제 : cat / 예측 : cat / 확률 : 0.9028
# 실제 : cat / 예측 : cat / 확률 : 0.8633
# 실제 : cat / 예측 : cat / 확률 : 0.7710
# 실제 : cat / 예측 : cat / 확률 : 0.9801
# 실제 : cat / 예측 : cat / 확률 : 0.8534
# 실제 : cat / 예측 : cat / 확률 : 0.9643
# 실제 : cat / 예측 : cat / 확률 : 0.9342
# 실제 : cat / 예측 : cat / 확률 : 0.9316
# 실제 : cat / 예측 : cat / 확률 : 0.6774
# 실제 : cat / 예측 : cat / 확률 : 0.9720
# 실제 : cat / 예측 : cat / 확률 : 0.9197
# 실제 : cat / 예측 : cat / 확률 : 0.8549
# 실제 : cat / 예측 : cat / 확률 : 0.9470
# 실제 : cat / 예측 : cat / 확률 : 0.9197
# 실제 : cat / 예측 : cat / 확률 : 0.8549
# 실제 : cat / 예측 : cat / 확률 : 0.9470
# 실제 : cat / 예측 : cat / 확률 : 0.9470
# 실제 : cat / 예측 : cat / 확률 : 0.9861
# 실제 : cat / 예측 : cat / 확률 : 0.4268
# 실제 : cat / 예측 : cat / 확률 : 0.8282
# 실제 : cat / 예측 : cat / 확률 : 0.7622
# 실제 : cat / 예측 : cat / 확률 : 0.8750
# 실제 : cat / 예측 : cat / 확률 : 0.9526
# 실제 : cat / 예측 : cat / 확률 : 0.9815
# 실제 : cat / 예측 : cat / 확률 : 0.9320
# 실제 : cat / 예측 : cat / 확률 : 0.7887
# 실제 : cat / 예측 : cat / 확률 : 0.7604
# 실제 : cat / 예측 : cat / 확률 : 0.7114
# 실제 : cat / 예측 : cat / 확률 : 0.6907
# 실제 : cat / 예측 : cat / 확률 : 0.5110
# 실제 : cat / 예측 : cat / 확률 : 0.9236
# 실제 : cat / 예측 : cat / 확률 : 0.7992
# 실제 : cat / 예측 : cat / 확률 : 0.4899
# 실제 : cat / 예측 : cat / 확률 : 0.5534
# 실제 : cat / 예측 : cat / 확률 : 0.8398
# 실제 : cat / 예측 : cat / 확률 : 0.6588
# 실제 : cat / 예측 : cat / 확률 : 0.9515
# 실제 : cat / 예측 : cat / 확률 : 0.9748
# 실제 : cat / 예측 : cat / 확률 : 0.8960
# 실제 : cat / 예측 : bird / 확률 : 0.5813
# 실제 : cat / 예측 : cat / 확률 : 0.6914
# 실제 : cat / 예측 : cat / 확률 : 0.8784
# 실제 : cat / 예측 : cat / 확률 : 0.8799
# 실제 : cat / 예측 : cat / 확률 : 0.5911
# 실제 : cat / 예측 : cat / 확률 : 0.6624
# 실제 : cat / 예측 : cat / 확률 : 0.5809
# 실제 : cat / 예측 : cat / 확률 : 0.9021
# 실제 : cat / 예측 : cat / 확률 : 0.9684
# 실제 : cat / 예측 : cat / 확률 : 0.8668
# 실제 : cat / 예측 : cat / 확률 : 0.9552
# 실제 : cat / 예측 : cat / 확률 : 0.8256
# 실제 : cat / 예측 : cat / 확률 : 0.6925
# 실제 : cat / 예측 : cat / 확률 : 0.7158
# 실제 : cat / 예측 : cat / 확률 : 0.8360
# 실제 : cat / 예측 : bird / 확률 : 0.4194
# 실제 : cat / 예측 : cat / 확률 : 0.5405
# 실제 : cat / 예측 : cat / 확률 : 0.7335
# 실제 : cat / 예측 : cat / 확률 : 0.7941
# 실제 : cat / 예측 : cat / 확률 : 0.9706
# 실제 : cat / 예측 : bird / 확률 : 0.4979
# 실제 : cat / 예측 : cat / 확률 : 0.9090
# 실제 : cat / 예측 : cat / 확률 : 0.9347
# 실제 : cat / 예측 : cat / 확률 : 0.6793
# 실제 : cat / 예측 : cat / 확률 : 0.7731
# 실제 : cat / 예측 : cat / 확률 : 0.8116
# 실제 : cat / 예측 : cat / 확률 : 0.8544
# 실제 : cat / 예측 : cat / 확률 : 0.8256
# 실제 : cat / 예측 : cat / 확률 : 0.8053
# 실제 : cat / 예측 : cat / 확률 : 0.9176
# 실제 : cat / 예측 : cat / 확률 : 0.6739
# 실제 : cat / 예측 : cat / 확률 : 0.8360
# 실제 : cat / 예측 : dog / 확률 : 0.6333
# 실제 : cat / 예측 : cat / 확률 : 0.7775
# 실제 : cat / 예측 : cat / 확률 : 0.9134
# 실제 : cat / 예측 : cat / 확률 : 0.9395
# 실제 : cat / 예측 : cat / 확률 : 0.9790
# 실제 : cat / 예측 : dog / 확률 : 0.5400
# 실제 : cat / 예측 : cat / 확률 : 0.8118
# 실제 : cat / 예측 : cat / 확률 : 0.8557
# 실제 : cat / 예측 : bird / 확률 : 0.5408
# 실제 : cat / 예측 : cat / 확률 : 0.9803
# 실제 : cat / 예측 : cat / 확률 : 0.5910
# 실제 : cat / 예측 : cat / 확률 : 0.8544
# 실제 : cat / 예측 : cat / 확률 : 0.8758
# 실제 : cat / 예측 : cat / 확률 : 0.8644
# 실제 : cat / 예측 : bird / 확률 : 0.5142
# 실제 : cat / 예측 : cat / 확률 : 0.6739
# 실제 : cat / 예측 : cat / 확률 : 0.5059
# 실제 : cat / 예측 : cat / 확률 : 0.4863
# 실제 : cat / 예측 : cat / 확률 : 0.7143
# 실제 : cat / 예측 : cat / 확률 : 0.6503
# 실제 : cat / 예측 : cat / 확률 : 0.9762
# 실제 : cat / 예측 : cat / 확률 : 0.9395
# 실제 : cat / 예측 : cat / 확률 : 0.9790
# 실제 : cat / 예측 : dog / 확률 : 0.5400
# 실제 : cat / 예측 : cat / 확률 : 0.8118
# 실제 : cat / 예측 : cat / 확률 : 0.8557
# 실제 : cat / 예측 : bird / 확률 : 0.5408
# 실제 : cat / 예측 : cat / 확률 : 0.9803
# 실제 : cat / 예측 : cat / 확률 : 0.5910
# 실제 : cat / 예측 : cat / 확률 : 0.8758
# 실제 : cat / 예측 : cat / 확률 : 0.8644
# 실제 : cat / 예측 : bird / 확률 : 0.5142
# 실제 : cat / 예측 : cat / 확률 : 0.5059
# 실제 : cat / 예측 : cat / 확률 : 0.4863
# 실제 : cat / 예측 : cat / 확률 : 0.7143
# 실제 : cat / 예측 : cat / 확률 : 0.6503
# 실제 : cat / 예측 : cat / 확률 : 0.9762
# 실제 : dog / 예측 : dog / 확률 : 0.9491
# 실제 : dog / 예측 : dog / 확률 : 0.9836
# 실제 : dog / 예측 : dog / 확률 : 0.9650
# 실제 : dog / 예측 : dog / 확률 : 0.9482
# 실제 : dog / 예측 : dog / 확률 : 0.9420
# 실제 : dog / 예측 : dog / 확률 : 0.8208
# 실제 : dog / 예측 : dog / 확률 : 0.9550
# 실제 : dog / 예측 : dog / 확률 : 0.9490
# 실제 : dog / 예측 : dog / 확률 : 0.8360
# 실제 : dog / 예측 : dog / 확률 : 0.9470
# 실제 : dog / 예측 : dog / 확률 : 0.9543
# 실제 : dog / 예측 : dog / 확률 : 0.8266
# 실제 : dog / 예측 : dog / 확률 : 0.9112
# 실제 : dog / 예측 : dog / 확률 : 0.9355
# 실제 : dog / 예측 : dog / 확률 : 0.9186
# 실제 : dog / 예측 : dog / 확률 : 0.9041
# 실제 : dog / 예측 : dog / 확률 : 0.8100
# 실제 : dog / 예측 : dog / 확률 : 0.9625
# 실제 : dog / 예측 : dog / 확률 : 0.8668
# 실제 : dog / 예측 : dog / 확률 : 0.8923
# 실제 : dog / 예측 : dog / 확률 : 0.9027
# 실제 : dog / 예측 : dog / 확률 : 0.8585
# 실제 : dog / 예측 : dog / 확률 : 0.9667
# 실제 : dog / 예측 : dog / 확률 : 0.9027
# 실제 : dog / 예측 : dog / 확률 : 0.8585
# 실제 : dog / 예측 : dog / 확률 : 0.9667
# 실제 : dog / 예측 : dog / 확률 : 0.9667
# 실제 : dog / 예측 : dog / 확률 : 0.9667
# 실제 : dog / 예측 : dog / 확률 : 0.9667
# 실제 : dog / 예측 : dog / 확률 : 0.7535
# 실제 : dog / 예측 : dog / 확률 : 0.7631
# 실제 : dog / 예측 : dog / 확률 : 0.5195
# 실제 : dog / 예측 : dog / 확률 : 0.8950
# 실제 : dog / 예측 : bird / 확률 : 0.5783
# 실제 : dog / 예측 : dog / 확률 : 0.5438
# 실제 : dog / 예측 : cat / 확률 : 0.8438
# 실제 : dog / 예측 : dog / 확률 : 0.8473
# 실제 : dog / 예측 : dog / 확률 : 0.8364
# 실제 : dog / 예측 : dog / 확률 : 0.7962
# 실제 : dog / 예측 : dog / 확률 : 0.6762
# 실제 : dog / 예측 : bird / 확률 : 0.5097
# 실제 : dog / 예측 : dog / 확률 : 0.7080
# 실제 : dog / 예측 : dog / 확률 : 0.8738
# 실제 : dog / 예측 : dog / 확률 : 0.8627
# 실제 : dog / 예측 : dog / 확률 : 0.8690
# 실제 : dog / 예측 : dog / 확률 : 0.6474
# 실제 : dog / 예측 : cat / 확률 : 0.3815
# 실제 : dog / 예측 : dog / 확률 : 0.8303
# 실제 : dog / 예측 : bird / 확률 : 0.5097
# 실제 : dog / 예측 : dog / 확률 : 0.6159
# 실제 : dog / 예측 : dog / 확률 : 0.6573
# 실제 : dog / 예측 : dog / 확률 : 0.6719
# 실제 : dog / 예측 : dog / 확률 : 0.7867
# 실제 : dog / 예측 : dog / 확률 : 0.5182
# 실제 : dog / 예측 : dog / 확률 : 0.6693
# 실제 : dog / 예측 : dog / 확률 : 0.6513
# 실제 : dog / 예측 : dog / 확률 : 0.8155
# 실제 : dog / 예측 : dog / 확률 : 0.9189
# 실제 : dog / 예측 : dog / 확률 : 0.5885
# 실제 : dog / 예측 : dog / 확률 : 0.4971
# 실제 : dog / 예측 : bird / 확률 : 0.4814
# 실제 : dog / 예측 : dog / 확률 : 0.7086
# 실제 : dog / 예측 : dog / 확률 : 0.7160
# 실제 : dog / 예측 : dog / 확률 : 0.7370
# 실제 : dog / 예측 : dog / 확률 : 0.7638
# 실제 : dog / 예측 : dog / 확률 : 0.5350
# 실제 : dog / 예측 : dog / 확률 : 0.4368
# 실제 : dog / 예측 : dog / 확률 : 0.6800
# 실제 : dog / 예측 : dog / 확률 : 0.9663
# 실제 : dog / 예측 : bird / 확률 : 0.4833
# 실제 : dog / 예측 : dog / 확률 : 0.7243
# 실제 : dog / 예측 : cat / 확률 : 0.5478
# 실제 : dog / 예측 : dog / 확률 : 0.6573
# 실제 : dog / 예측 : dog / 확률 : 0.4374
# 실제 : dog / 예측 : dog / 확률 : 0.9797
# 실제 : dog / 예측 : dog / 확률 : 0.7433
# 실제 : dog / 예측 : dog / 확률 : 0.8292
# 실제 : dog / 예측 : dog / 확률 : 0.7739
# 실제 : dog / 예측 : dog / 확률 : 0.6513
# 실제 : dog / 예측 : dog / 확률 : 0.6644
# 실제 : dog / 예측 : dog / 확률 : 0.5885
# 실제 : dog / 예측 : dog / 확률 : 0.4971
# 실제 : dog / 예측 : bird / 확률 : 0.4814
# 실제 : dog / 예측 : dog / 확률 : 0.7086
# 실제 : dog / 예측 : dog / 확률 : 0.7160
# 실제 : dog / 예측 : dog / 확률 : 0.7638
# 실제 : dog / 예측 : dog / 확률 : 0.7370
# 실제 : dog / 예측 : dog / 확률 : 0.5350
# 실제 : dog / 예측 : dog / 확률 : 0.4368
# 실제 : dog / 예측 : dog / 확률 : 0.6800
# 실제 : dog / 예측 : dog / 확률 : 0.9663
# 실제 : dog / 예측 : bird / 확률 : 0.4834
# 실제 : dog / 예측 : cat / 확률 : 0.5867
# 실제 : dog / 예측 : dog / 확률 : 0.7243
# 실제 : dog / 예측 : cat / 확률 : 0.5476
# 실제 : dog / 예측 : dog / 확률 : 0.4374
# 실제 : dog / 예측 : dog / 확률 : 0.9797
# 실제 : dog / 예측 : dog / 확률 : 0.7979
# 실제 : dog / 예측 : dog / 확률 : 0.7434
# 실제 : dog / 예측 : dog / 확률 : 0.8293
# 실제 : dog / 예측 : dog / 확률 : 0.7740

# %% [markdown]
# ## 10. 시각화

# %%
# images, labels = next(iter(test_loader))
batch_size = 8
all_batches = list(test_loader)
images, labels = all_batches[14]  

model.eval()

with torch.no_grad():
    outputs = model(images.to(device))

    prob = torch.softmax(outputs, dim=1)
    confidence, predict = torch.max(prob, 1)

plt.figure(figsize=(12, 6))

for i in range(min(8, len(images))):
    image = images[i].permute(1, 2, 0).numpy() 

    true_label = class_names[labels[i].item()]
    pred_label = class_names[predict[i].item()]

    conf = confidence[i].item()

    # 2행 4열 형태로 이미지출력
    plt.subplot(2, 4, i+ 1)
    plt.imshow(image)
    plt.title(f'True : {true_label} / Pred : {pred_label} / Acc : {conf:.2f}')
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 2026-05-21 16:58:46,890 - WARNING - matplotlib.image - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0494049..2.64].
# 2026-05-21 16:58:46,899 - WARNING - matplotlib.image - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0665298..2.64].
# 2026-05-21 16:58:47,020 - WARNING - matplotlib.image - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# 2026-05-21 16:58:47,026 - WARNING - matplotlib.image - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.4831376].
# 2026-05-21 16:58:47,030 - WARNING - matplotlib.image - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# 2026-05-21 16:58:47,036 - WARNING - matplotlib.image - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9637812..2.64].
# 2026-05-21 16:58:47,041 - WARNING - matplotlib.image - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.5877128].
# 2026-05-21 16:58:47,047 - WARNING - matplotlib.image - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.1007793..2.622571].
